# %% [markdown]
# **Flying High and Flying Low: Budget and Charter Flights at San Francisco International Airport**
#
# This project examines two datasets from the San Francisco open data portal: [Air Traffic Landings Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Landings-Statistics/fpux-q53t) and [Air Traffic Passenger Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg) in order to determine how changing income inequality in the Bay Area has impacted the prevalence of budget vs. charter airlines at SFO. This story asks four main questions:
# 1. Has the number of budget flights increased or decreased with time?
# 2. Has the number of passengers flying via budget airlines increased or decreased with time?
# 3. Has the number of charter flights increased or decreased with time?
# 4. Has the number of passengers flying via charter airlines increased or decreased with time?
#
# The [Air Traffic Landings Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Landings-Statistics/fpux-q53t) dataset contains monthly information about how many flights a specific airline is operating. I used this dataset to answer research questions 1 and 2.
#
# The [Air Traffic Passenger Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg) dataset contains monthly information about how many passengers a specific airline is transporting. I used this dataset to answer research questions 3 and 4.
#
# **Results:**
# 1. I found that the number of budget flights has increased while the number of passengers flying via budget flights has decreased.
# 2. I found that the number of charter flights as well as the number of passengers flying via charter flights has increased.
#
# Because the airport has limited space, the allocation of that space to individual flights can reflect local priorities. More and more of SFO's space is being allocated to chartered flights over budget flights, which reflects San Francisco's growing wealth inequality. As the technology industry funnels more and more wealth into the Bay Area, the wealthy patrons of charter airlines are better able to exploit the limited resources at SFO than the less wealthy patrons of budget airlines.
#
# **Step 1: Manual Creation of a List of Budget and Charter Airlines**
#
# In order to get a comprehensive list of the airlines at SFO, I used four datasets available on the San Francisco open data portal: [Air Traffic Landings Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Landings-Statistics/fpux-q53t), [Air Traffic Passenger Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg), [Aircraft Parking Activity Records at SFO](https://data.sfgov.org/Transportation/Aircraft-Parking-Activity-Records-at-SFO/5rkh-waic), and [Aircraft Tail Numbers and Models at SFO](https://data.sfgov.org/Transportation/Aircraft-Tail-Numbers-and-Models-at-SFO/u7dr-xm3v). Each entry in the datasets lists an airline, and I aggregated the unique entries in each dataset to obtain a comprehensive look at every known airline operating out of the airport. Lastly, for each unique airline, I tagged the ones that were charter or budget airlines. For a peek at that database, see below:

# %%
import pandas as pd
budget_vs_charter_airlines = 'data/raw/charter_and_budget_airlines.csv'
airlines = pd.read_csv(budget_vs_charter_airlines)
airlines.head(10)
# Out:
#                    Airline  Charter?  Low Cost?
# 0             ATA Airlines     False       True
# 1          AirTran Airways     False       True
# 2        Frontier Airlines     False       True
# 3         Independence Air     False       True
# 4     Sun Country Airlines     False       True
# 5  Miami Air International      True      False
# 6          Spirit Airlines     False       True
# 7             Xtra Airways      True      False
# 8            Allegiant Air     False       True
# 9               Air Berlin     False       True

# %% [markdown]
# From there, I created a list of every budget airline and every charter airline operating out of SFO.
#
# **Step 2: Scripted cleaning of [Air Traffic Landings Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Landings-Statistics/fpux-q53t) and [Air Traffic Passenger Statistics](https://data.sfgov.org/Transportation/Air-Traffic-Passenger-Statistics/rkru-6vcg) databases**
#
# I filtered the two databases with a python script called clean_all_datasets.py, using the two lists for chartered and budget airlines in order to create four databases: Budget Airline Landings, Charter Airline Landings, Budget Airline Passengers, and Charter Airline Passengers.
#
# For a peek at those databases, see below:

# %%
print("BUDGET LANDINGS")
budget_landings = pd.read_csv('data/processed/clean_budget_Air_Traffic_Landings_Statistics.csv').sort_values("Activity Period", ascending=True)
budget_landings.head(10)
# Out:
# BUDGET LANDINGS
#     Activity Period     Operating Airline Operating Airline IATA Code  \
# 0              2006          ATA Airlines                          TZ
# 34             2006  Sun Country Airlines                          SY
# 35             2006       AirTran Airways                          FL
# 36             2006     Frontier Airlines                          F9
# 37             2006     Frontier Airlines                          F9
# 38             2006       Spirit Airlines                          NK
# 39             2006  Sun Country Airlines                          SY
# 40             2006       AirTran Airways                          FL
# 41             2006     Frontier Airlines                          F9
# 42             2006       Spirit Airlines                          NK
#
#        Published Airline Published Airline IATA Code GEO Summary GEO Region  \
# 0           ATA Airlines                          TZ    Domestic         US
# 34  Sun Country Airlines                          SY    Domestic         US
# 35       AirTran Airways                          FL    Domestic         US
# 36     Frontier Airlines                          F9    Domestic         US
# 37     Frontier Airlines                          F9    Domestic         US
# 38       Spirit Airlines                          NK    Domestic         US
# 39  Sun Country Airlines                          SY    Domestic         US
# 40       AirTran Airways                          FL    Domestic         US
# 41     Frontier Airlines                          F9    Domestic         US
# 42       Spirit Airlines                          NK    Domestic         US
#
#    Landing Aircraft Type Aircraft Body Type Aircraft Manufacturer  \
# 0              Passenger        Narrow Body                Boeing
# 34             Passenger        Narrow Body                Boeing
# 35             Passenger        Narrow Body                Boeing
# 36             Passenger        Narrow Body                Airbus
# 37             Passenger        Narrow Body                Airbus
# 38             Passenger        Narrow Body                Airbus
# 39             Passenger        Narrow Body                Boeing
# 40             Passenger        Narrow Body                Boeing
# 41             Passenger        Narrow Body                Airbus
# 42             Passenger        Narrow Body                Airbus
#
#    Aircraft Model Aircraft Version  Landing Count  Total Landed Weight
# 0             737              800            124             18141200
# 34            737              800             30              4384200
# 35            737              700             93             11904000
# 36           A318              NaN              1               123500
# 37           A319              NaN            290             39005000
# 38           A319              NaN             31              4271800
# 39            737              800             31              4532900
# 40            737              700            117             14976000
# 41           A319              NaN            292             39274000
# 42           A319              NaN             31              4271800

# %%
print("BUDGET PASSENGERS")
budget_passengers = pd.read_csv('data/processed/clean_budget_Air_Traffic_Passenger_Statistics.csv').sort_values("Activity Period", ascending=True)
budget_passengers.head(10)
# Out:
# BUDGET PASSENGERS
#       Activity Period     Operating Airline Operating Airline IATA Code  \
# 413              2006  Sun Country Airlines                          SY
# 1031             2006     Frontier Airlines                          F9
# 89               2006       Spirit Airlines                          NK
# 919              2006     Frontier Airlines                          F9
# 769              2006       AirTran Airways                          FL
# 671              2006       AirTran Airways                          FL
# 458              2006       AirTran Airways                          FL
# 667              2006       AirTran Airways                          FL
# 461              2006       AirTran Airways                          FL
# 664              2006       AirTran Airways                          FL
#
#          Published Airline Published Airline IATA Code GEO Summary GEO Region  \
# 413   Sun Country Airlines                          SY    Domestic         US
# 1031     Frontier Airlines                          F9    Domestic         US
# 89         Spirit Airlines                          NK    Domestic         US
# 919      Frontier Airlines                          F9    Domestic         US
# 769        AirTran Airways                          FL    Domestic         US
# 671        AirTran Airways                          FL    Domestic         US
# 458        AirTran Airways                          FL    Domestic         US
# 667        AirTran Airways                          FL    Domestic         US
# 461        AirTran Airways                          FL    Domestic         US
# 664        AirTran Airways                          FL    Domestic         US
#
#      Activity Type Code Price Category Code       Terminal Boarding Area  \
# 413            Enplaned            Low Fare     Terminal 1             B
# 1031           Deplaned            Low Fare     Terminal 1             C
# 89             Enplaned            Low Fare  International             A
# 919            Enplaned            Low Fare     Terminal 1             B
# 769            Deplaned            Low Fare  International             A
# 671            Enplaned            Low Fare  International             A
# 458            Enplaned            Low Fare  International             A
# 667            Enplaned            Low Fare     Terminal 1             B
# 461            Deplaned            Low Fare  International             A
# 664            Enplaned            Low Fare  International             A
#
#       Passenger Count
# 413              3738
# 1031            18748
# 89                802
# 919             14927
# 769             10421
# 671              7579
# 458              4057
# 667              7536
# 461              4096
# 664              7453

# %%
print("CHARTER LANDINGS")
charter_landings = pd.read_csv('data/processed/clean_charter_Air_Traffic_Landings_Statistics.csv').sort_values("Activity Period", ascending=True)
charter_landings.head(10)
# Out:
# CHARTER LANDINGS
#     Activity Period                  Operating Airline  \
# 0              2006                       Xtra Airways
# 1              2007            Miami Air International
# 2              2007            Miami Air International
# 3              2008            Miami Air International
# 4              2008            Miami Air International
# 5              2008            Miami Air International
# 6              2008            Miami Air International
# 7              2009            Miami Air International
# 11             2011  Air Transport International, LLC.
# 10             2011  Air Transport International, LLC.
#
#    Operating Airline IATA Code                  Published Airline  \
# 0                           XP                       Xtra Airways
# 1                           GL            Miami Air International
# 2                           GL            Miami Air International
# 3                           GL            Miami Air International
# 4                           GL            Miami Air International
# 5                           GL            Miami Air International
# 6                           GL            Miami Air International
# 7                           GL            Miami Air International
# 11                         NaN  Air Transport International, LLC.
# 10                         NaN  Air Transport International, LLC.
#
#    Published Airline IATA Code GEO Summary GEO Region Landing Aircraft Type  \
# 0                           XP    Domestic         US             Passenger
# 1                           GL    Domestic         US             Passenger
# 2                           GL    Domestic         US             Passenger
# 3                           GL    Domestic         US             Passenger
# 4                           GL    Domestic         US             Passenger
# 5                           GL    Domestic         US             Passenger
# 6                           GL    Domestic         US             Passenger
# 7                           GL    Domestic         US             Passenger
# 11                         NaN    Domestic         US             Freighter
# 10                         NaN    Domestic         US             Freighter
#
#    Aircraft Body Type Aircraft Manufacturer Aircraft Model Aircraft Version  \
# 0         Narrow Body                Boeing            737              400
# 1         Narrow Body                Boeing            737              400
# 2         Narrow Body                Boeing            737              800
# 3         Narrow Body                Boeing            737              800
# 4         Narrow Body                Boeing            737              800
# 5         Narrow Body                Boeing            737              400
# 6         Narrow Body                Boeing            737              800
# 7         Narrow Body                Boeing            737              800
# 11        Narrow Body     McDonnell Douglas           DC-8                -
# 10        Narrow Body     McDonnell Douglas           DC-8                -
#
#     Landing Count  Total Landed Weight
# 0               1               124000
# 1               1               121000
# 2               1               146000
# 3               1               146000
# 4               1               146000
# 5               1               121000
# 6               1               146000
# 7               2               291984
# 11              1               275000
# 10             20              5262000

# %%
print("CHARTER PASSENGERS")
charter_passengers = pd.read_csv('data/processed/clean_charter_Air_Traffic_Passenger_Statistics.csv').sort_values("Activity Period", ascending=True)
charter_passengers.head(10)
# Out:
# CHARTER PASSENGERS
#     Activity Period        Operating Airline Operating Airline IATA Code  \
# 9              2006             Xtra Airways                          XP
# 10             2006             Xtra Airways                          XP
# 6              2007  Miami Air International                          GL
# 20             2007  Miami Air International                          GL
# 18             2007  Miami Air International                          GL
# 13             2008  Miami Air International                          GL
# 4              2008  Miami Air International                          GL
# 5              2008  Miami Air International                          GL
# 12             2008  Miami Air International                          GL
# 17             2008  Miami Air International                          GL
#
#           Published Airline Published Airline IATA Code GEO Summary  \
# 9              Xtra Airways                          XP    Domestic
# 10             Xtra Airways                          XP    Domestic
# 6   Miami Air International                          GL    Domestic
# 20  Miami Air International                          GL    Domestic
# 18  Miami Air International                          GL    Domestic
# 13  Miami Air International                          GL    Domestic
# 4   Miami Air International                          GL    Domestic
# 5   Miami Air International                          GL    Domestic
# 12  Miami Air International                          GL    Domestic
# 17  Miami Air International                          GL    Domestic
#
#    GEO Region Activity Type Code Price Category Code       Terminal  \
# 9          US           Deplaned               Other  International
# 10         US           Enplaned               Other  International
# 6          US           Enplaned               Other  International
# 20         US           Deplaned               Other  International
# 18         US           Enplaned               Other  International
# 13         US           Deplaned               Other  International
# 4          US           Deplaned               Other  International
# 5          US           Enplaned               Other  International
# 12         US           Deplaned               Other  International
# 17         US           Enplaned               Other  International
#
#    Boarding Area  Passenger Count
# 9              A               73
# 10             A               73
# 6              A               64
# 20             A              167
# 18             A              166
# 13             A               86
# 4              A               58
# 5              A               60
# 12             A               85
# 17             A              164

# %% [markdown]
# **Step 3: Using Pandas to Answer the Questions**
#
# I will repeat the same data processing procedure for each of these four questions:
# 1. Has the number of budget flights increased or decreased with time?
# 2. Has the number of passengers flying via budget airlines increased or decreased with time?
# 3. Has the number of charter flights increased or decreased with time?
# 4. Has the number of passengers flying via charter airlines increased or decreased with time?
#
# For clarity, I will fully explain the methodology of the first and simply do the data processing for 2-4.
#
# Each database includes multiple entries per month. To get a month-by-month look at changes in charter and budget flight data, I consolidated the entries by 'Activity Period' (each activity period represents one month) using Pandas' GroupBy function.

# %% [markdown]
# **Question 1: Has the number of budget flights increased or decreased with time?**
#
# To answer this question, we will look at the Budget Landings database.
#
# At the moment, each entry represents the number of flights by a particular airline in a particular month. We want to add all the entries that take place in a particular year to get the total value. We can use the Pandas GroupBy function to add up all the values for 'Landing Count' in rows with the same value for 'Activity Period.'
#
# (For clarity, we also drop 'Total Landed Weight' in this dataframe as well as the dataframe for Charter Landings.)
#
# Lastly, we want to drop the values for 'Landing Count' that are recorded in the years 2005 and 2019, as those were both partial years.

# %%
print("BUDGET LANDINGS")
budget_landings_by_year = budget_landings.groupby("Activity Period").sum().drop('Total Landed Weight', axis=1)
budget_landings_by_year.head(10)
# Out:
# BUDGET LANDINGS
#                  Landing Count
# Activity Period
# 2006                      4476
# 2007                      4762
# 2008                      2969
# 2009                      2739
# 2010                      3371
# 2011                      3969
# 2012                      3694
# 2013                      2768
# 2014                      2502
# 2015                      2843

# %% [markdown]
# Now let's look at the graph! (Here, we use the matplotlib library to make a quick, easy plot of the landings.)

# %%
budget_landings_by_year.plot()

# %% [markdown]
# **Answer: The number of budget flights seems to have decreased over time.**
#
# Though the pattern shows a lot of variation, there seems to be a steady decline in the number of budget flights over time.
#
# Further questions: why do increases and decreases occur on roughly 5-year intervals? What factors could be driving these increases and decreases?

# %% [markdown]
# **Question 2: Has the number of budget passengers increased or decreased with time?**

# %%
print("BUDGET PASSENGERS")
budget_passengers_by_year = budget_passengers.groupby("Activity Period").sum()
budget_passengers_by_year.head(10)
# Out:
# BUDGET PASSENGERS
#                  Passenger Count
# Activity Period
# 2006                      854632
# 2007                      884631
# 2008                      676288
# 2009                      640636
# 2010                      805269
# 2011                      967839
# 2012                      907367
# 2013                      678884
# 2014                      635467
# 2015                      756726

# %% [markdown]
# Now let's look at the graph!

# %%
budget_passengers_by_year.plot()

# %% [markdown]
# **Answer: The number of budget passengers seems to have increased over time.**
#
# Though the pattern shows a lot of variation, it looks like there may be an increase in the number of budget passengers over time.
#
# Further questions: Does this graph actually represent a steady increase given the extreme fluctuations? Why do increases and decreases occur on roughly 5-year intervals? What factors could be driving these increases and decreases? If there are fewer budget flights and more budget passengers, does this mean that budget flights are getting larger?

# %% [markdown]
# **Question 3: Has the number of charter flights increased or decreased with time?**

# %%
print("CHARTER LANDINGS")
charter_landings_by_year = charter_landings.groupby("Activity Period").sum().drop('Total Landed Weight', axis=1)
charter_landings_by_year.head(10)
# Out:
# CHARTER LANDINGS
#                  Landing Count
# Activity Period
# 2006                         1
# 2007                         2
# 2008                         4
# 2009                         2
# 2011                        58
# 2012                       274
# 2013                       312
# 2014                         8
# 2015                       747
# 2016                      1215

# %% [markdown]
# Now let's look at the graph!

# %%
charter_landings_by_year.plot()

# %% [markdown]
# **Answer: The number of charter flights has increased over time.**
#
# There has been a massive increase in the number of charter flights since roughly 2014.
#
# Further questions: What happened in 2014 that increased the number of chartered flights? What factors are influencing the massive increase of charter flights as well as the drop in 2014?

# %% [markdown]
# **Question 4: Has the number of passengers flying via charter airlines increased or decreased with time?**

# %%
print("CHARTER PASSENGERS")
charter_passengers_by_year = charter_passengers.groupby("Activity Period").sum()
charter_passengers_by_year.head(10)
# Out:
# CHARTER PASSENGERS
#                  Passenger Count
# Activity Period
# 2006                         146
# 2007                         397
# 2008                         589
# 2009                         108
# 2011                         430
# 2013                         136
# 2015                         166
# 2017                       26693
# 2018                       36665

# %% [markdown]
# Now let's look at the graph!

# %%
charter_passengers_by_year.plot()

# %% [markdown]
# **Answer: The number of charter passengers has increased over time.**
#
# There has been a massive increase in the number of charter passengers since roughly 2015.
#
# Further questions: What happened in 2015 that increased the number of chartered passengers? What factors are influencing the massive increase of charter passengers? Why was there an increase in charter flights in 2010-2014 without an increase in charter passengers? What happened in 2015 that wildly increased the number of both flights and passengers?

# %% [markdown]
# **Takeaways**
#
# There has been a massive increase in the number of charter flights taken from SFO, both in the number of passengers flying and the number of flights. Meanwhile, there has been a decrease in budget flights and fluctuation in the number of budget passengers. This indicates that the limited resources at SFO are being increasingly allocated to the very wealthy and very few, which raises questions about the priorities of the local government that owns and operates SFO as well as the local population that elects and oversees that government. Though the factors that shape patterns in budget and chartered flight frequency are complex, the data clearly demonstrates that shared public resources are increasingly being allocated towards the few.
